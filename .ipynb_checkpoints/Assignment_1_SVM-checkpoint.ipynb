# %%
# import packages
import pandas as pd
import numpy as np
from plotnine import *
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
# import data
data = pd.read_csv('iris-1.csv')

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# visualize dataframe
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
# see what columns are in the dataframe; Species is the main class label
data.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
# observe the different values used for species - 2 different values: 'Iris-setosa', 'Not-Iris-setosa'
data['Species'].unique()
# Out:
# array(['Iris-setosa', 'Not-Iris-setosa'], dtype=object)

# %%
# check if there are missing values in the dataframe - there are no missing values
data.isnull().sum(axis=0)
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
# do not include Id as a feature
features = ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']
output = ['Species']

# %%
''' TODO: Should I plot the different features against one another with color labels that distinguish the different
classes to visualize the relationships between the different continuous features? '''
# Out:
# ' TODO: Should I plot the different features against one another with color labels that distinguish the different\nclasses to visualize the relationships between the different continuous features? '

# %%
def graph_feature_by_species(x, y):
    return (ggplot(data, aes(x=x, y=y, color='Species')) 
     + geom_point()
     + theme_minimal()
    )

# %%
# create a graph for each feature - Note: every feature appears to be linearly separable
for feature in features:
    print(graph_feature_by_species('Id', feature))

# %%
# Split Data in test/train (80/20)
z = StandardScaler()
X_train, X_test, y_train, y_test = train_test_split(data[features], data[output], test_size=0.2)
print(X_train)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 29             4.7           3.2            1.6           0.2
# 27             5.2           3.5            1.5           0.2
# 149            5.9           3.0            5.1           1.8
# 54             6.5           2.8            4.6           1.5
# 89             5.5           2.5            4.0           1.3
# ..             ...           ...            ...           ...
# 117            7.7           3.8            6.7           2.2
# 55             5.7           2.8            4.5           1.3
# 59             5.2           2.7            3.9           1.4
# 115            6.4           3.2            5.3           2.3
# 112            6.8           3.0            5.5           2.1
#
# [120 rows x 4 columns]

# %%
'''
TODO: ask if I need to convert classification data to continuous via incrementer like get_dummies
'''
# Out:
# '\nTODO: ask if I need to convert classification data to continuous via incrementer like get_dummies\n'

# %%
# Z-Score the train and test data sets
# for train, transform the data and then fit it to the model
X_train = z.fit_transform(X_train)
# for test, transform the data, but do not fit it to the model to prevent bias/overfitting
X_test = z.transform(X_test)
print(X_train)
# Out:
# [[-1.38907359  0.2748093  -1.20508529 -1.28357335]
#  [-0.78204945  0.98654562 -1.26152957 -1.28357335]
#  [ 0.06778436 -0.19968158  0.77046437  0.79965643]
#  [ 0.79621334 -0.67417246  0.48824299  0.40905085]
#  [-0.41783496 -1.38590877  0.14957733  0.14864713]
#  [-0.90345428  0.74930018 -1.26152957 -1.28357335]
#  [ 1.16042783 -0.67417246  0.60113154  0.27884899]
#  [ 0.31059402 -0.67417246  0.14957733  0.14864713]
#  [ 2.2530713  -0.67417246  1.67357279  1.06006015]
#  [-1.14626393  0.03756386 -1.26152957 -1.41377521]
#  [-0.53923979  1.93552737 -1.14864102 -1.02316963]
#  [-0.1750253  -0.19968158  0.26246588  0.01844526]
#  [ 0.31059402 -0.19968158  0.65757582  0.79965643]
#  [-1.26766876  0.74930018 -1.03575247 -1.28357335]
#  [-1.14626393  0.03756386 -1.26152957 -1.41377521]
#  [-1.51047842  1.22379106 -1.54375095 -1.28357335]
#  [ 1.76745198 -0.43692702  1.44779568  0.79965643]
#  [-1.26766876 -0.19968158 -1.31797385 -1.41377521]
# ...

# %%
# Init the SVM Model
SVM_Model = SVC(kernel='linear')

# %%
# Train the SVM Model
SVM_Model.fit(X_train, y_train.values.ravel())
# .values will give the values in an array. (shape: (n,1) 
# .ravel will convert that array shape to (n, )
# Source: https://stackoverflow.com/questions/34165731/a-column-vector-y-was-passed-when-a-1d-array-was-expected
# Out:
# SVC(kernel='linear')

# %%
# Testing the SVM Model
y_pred = SVM_Model.predict(X_test)

# %%
acc_score = accuracy_score(y_test, y_pred)
print(acc_score)
# Out:
# 1.0

# %%
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[ 9  0]
#  [ 0 21]]
